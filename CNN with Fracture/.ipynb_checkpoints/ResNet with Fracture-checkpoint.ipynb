# %%
from __future__ import print_function
import sys
sys.setrecursionlimit(99999)
import pdb

import numpy as np
np.random.seed(1337)  # for reproducibility

import keras

from keras.datasets import mnist, cifar10
from keras.models import Sequential, Graph
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import ZeroPadding2D, AveragePooling2D, Convolution2D
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras.layers.normalization import BatchNormalization

import residual_blocks


batch_size = 2
nb_classes = 1
nb_epoch = 200

def compute_padding_length(length_before, stride, length_conv):
    ''' Assumption: you want the subsampled result has a length of floor(original_length/stride).
    '''
    N = length_before
    F = length_conv
    S = stride
    if S == F:
        return 0
    if S == 1:
        return (F-1)/2
    for P in range(S):
        if (N-F+2*P)/S + 1 == N/S:
            return P
    return 0

def design_for_residual_blocks(num_channel_input=1):
    ''''''
    model = Sequential() # it's a CONTAINER, not MODEL
    # set numbers
#     num_big_blocks = 6
#     image_patch_sizes = [[6,6],[6,6],[9,9],[9,9],[9,9],[9,9]]
#     pool_sizes = [(2,2)]*num_big_blocks
#     n_features = [24, 24, 40, 40, 288, 288]
#     n_features_next = [24, 40, 40, 288, 288,288]
#     height_input = 144
#     width_input = 144
    num_big_blocks = 21
    image_patch_sizes = [[3,3]]*num_big_blocks
    pool_sizes = [(2,2)]*num_big_blocks
    n_features =      [24,24,24,24,48,48,48,64,96,96,96, 128,128,128,192,192,192,192,384,384,384]
    n_features_next = [24,24,24,48,48,64,48,96,96,96,128,128,128,192,192,192,192,384,384,384,384]
    height_input = 144
    width_input = 144
    
    for conv_idx in range(num_big_blocks):    
        n_feat_here = n_features[conv_idx]
        # residual block 0
        model.add(residual_blocks.building_residual_block(  (num_channel_input, height_input, width_input),
                                                            n_feat_here,
                                                            kernel_sizes=image_patch_sizes[conv_idx]
                                                            ))

        # residual block 1 (you can add it as you want (and your resources allow..))
        if False:
            model.add(residual_blocks.building_residual_block(  (n_feat_here, height_input, width_input),
                                                                n_feat_here,
                                                                kernel_sizes=image_patch_sizes[conv_idx]
                                                                ))
        
        # the last residual block N-1
        # the last one : pad zeros, subsamples, and increase #channels
        pad_height = compute_padding_length(height_input, pool_sizes[conv_idx][0], image_patch_sizes[conv_idx][0])
        pad_width = compute_padding_length(width_input, pool_sizes[conv_idx][1], image_patch_sizes[conv_idx][1])

        model.add(ZeroPadding2D(padding=(pad_height,pad_width))) 
        height_input += 2*pad_height
        width_input += 2*pad_width
        n_feat_next = n_features_next[conv_idx]
        if n_features[conv_idx]!=n_features_next[conv_idx]:
            model.add(residual_blocks.building_residual_block(  (n_feat_here, height_input, width_input),
                                                                n_feat_next,
                                                                kernel_sizes=image_patch_sizes[conv_idx],
                                                                is_subsample=True,
                                                                subsample=pool_sizes[conv_idx]
                                                                ))

        height_input, width_input = model.output_shape[2:]
        # width_input  = int(width_input/pool_sizes[conv_idx][1])
        num_channel_input = n_feat_next

    # Add average pooling at the end:
    print('Average pooling, from (%d,%d) to (1,1)' % (height_input, width_input))
    model.add(AveragePooling2D(pool_size=(height_input, width_input)))

    return model

def get_residual_model(is_mnist=True, img_channels=1, img_rows=144, img_cols=144):
    model = keras.models.Sequential()
    first_layer_channel = 24
    if is_mnist: # size to be changed to 32,32
        model.add(ZeroPadding2D((0,0), input_shape=(img_channels, img_rows, img_cols))) # resize (28,28)-->(32,32)
        # the first conv 
        model.add(Convolution2D(first_layer_channel, 3, 3, border_mode='same'))
    else:
        model.add(Convolution2D(first_layer_channel, 3, 3, border_mode='same', input_shape=(img_channels, img_rows, img_cols)))

    model.add(Activation('relu'))
    # [residual-based Conv layers]
    residual_blocks = design_for_residual_blocks(num_channel_input=first_layer_channel)
    model.add(residual_blocks)
    model.add(BatchNormalization(axis=1))
    model.add(Activation('relu'))
    # [Classifier]    
    model.add(Flatten())
    model.add(Dense(nb_classes))
    model.add(Activation('linear'))
    # [END]
    return model

def exp_error(y_true, y_pred):
    return K.mean(K.square(np.exp(y_pred) - np.exp(y_true)))


if __name__ =='__main__':
    
    is_mnist = True
    is_cifar10 = not is_mnist
    
    if is_mnist:
        import scipy.io as sio
        import numpy as np
        img_rows, img_cols = 144, 144
        img_channels = 1
        WB=sio.loadmat('WB_small.mat')['WB_small'].T
        Y_data=sio.loadmat('true.mat')['skt']
        Y_data=(Y_data-min(Y_data))/(max(Y_data)-min(Y_data))
        X_data=np.reshape(WB,(100,1,img_rows,img_cols))
        X_train=X_data[0:80];X_test=X_data[80:100]
        Y_train=Y_data[0:80];Y_test=Y_data[80:100]
        print(' == MNIST ==')
#         (X_train, y_train), (X_test, y_test) = mnist.load_data()
#         img_rows, img_cols = 28, 28
#         img_channels = 1
#         print(' == MNIST ==')

    X_train = X_train.reshape(X_train.shape[0], img_channels, img_rows, img_cols)
    X_test = X_test.reshape(X_test.shape[0], img_channels, img_rows, img_cols)
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    # X_train /= 255
    # X_test /= 255
    #X_train = (X_train - np.mean(X_train))/np.std(X_train)
    #X_test = (X_test - np.mean(X_test))/np.std(X_test)
    
#     X_train = (X_train - np.mean(X_train))/np.std(X_train)
#     X_test = (X_test - np.mean(X_test))/np.std(X_test)
#     Y_train = y_train
#     Y_test = y_test
    print('X_train shape:', X_train.shape)
    print(X_train.shape[0], 'train samples')
    print(X_test.shape[0], 'test samples')

    model = get_residual_model(is_mnist=is_mnist, img_channels=img_channels, img_rows=img_rows, img_cols=img_cols)

    model.compile(loss='mae', optimizer='adam', metrics=['accuracy'])

#     # autosave best Model
#     best_model_file = "./my_model_weights.h5"
#     best_model = ModelCheckpoint(best_model_file, verbose=1, save_best_only=True)
    
#     model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch,
#               verbose=1, validation_data=(X_test, Y_test))#, callbacks=[best_model])
#     score = model.evaluate(X_test, Y_test, show_accuracy=True, verbose=0)
# Out:
# Using Theano backend.
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptckrru/265abc51f7c376c224983485238ff1a5.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptckrru/265abc51f7c376c224983485238ff1a5.exp
#
# Using gpu device 0: Quadro K2000 (CNMeM is disabled, cuDNN 5005)
#  == MNIST ==
# X_train shape: (80L, 1L, 144L, 144L)
# 80 train samples
# 20 test samples
#    - New residual block with
# ('      input shape:', (24, 144, 144))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (24, 146, 146))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (24, 148, 148))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (24, 150, 150))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (24, 152, 152))
# ('      kernel size:', [3, 3])
#       - Input channels: 24 ---> num feature maps on out: 48
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (48, 76, 76))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (48, 78, 78))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (48, 80, 80))
# ('      kernel size:', [3, 3])
#       - Input channels: 48 ---> num feature maps on out: 64
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (64, 40, 40))
# ('      kernel size:', [3, 3])
#       - Input channels: 64 ---> num feature maps on out: 48
#         -- model was built.
#    - New residual block with
# ('      input shape:', (48, 42, 42))
# ('      kernel size:', [3, 3])
#       - Input channels: 48 ---> num feature maps on out: 64
#         -- model was built.
#    - New residual block with
# ('      input shape:', (64, 44, 44))
# ('      kernel size:', [3, 3])
#       - Input channels: 64 ---> num feature maps on out: 96
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (96, 22, 22))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (96, 24, 24))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (96, 26, 26))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (96, 28, 28))
# ('      kernel size:', [3, 3])
#       - Input channels: 96 ---> num feature maps on out: 128
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (128, 14, 14))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (128, 16, 16))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (128, 18, 18))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (128, 20, 20))
# ('      kernel size:', [3, 3])
#       - Input channels: 128 ---> num feature maps on out: 192
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (192, 10, 10))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (192, 12, 12))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (192, 14, 14))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (192, 16, 16))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (192, 18, 18))
# ('      kernel size:', [3, 3])
#       - Input channels: 192 ---> num feature maps on out: 384
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (384, 9, 9))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (384, 9, 9))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (384, 9, 9))
# ('      kernel size:', [3, 3])
#         -- model was built.
# Average pooling, from (9,9) to (1,1)

# %%
model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=500,verbose=1, validation_data=(X_test, Y_test))
# Out:
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpuyysdt/e27d3604e20e1a2d817586b7e9b57f6e.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpuyysdt/e27d3604e20e1a2d817586b7e9b57f6e.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptnitut/df6a62a4e50c19a1378f09e7f6663bbd.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptnitut/df6a62a4e50c19a1378f09e7f6663bbd.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpkrbacb/ee7d708e97835d0b04fd7362f7fffab4.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpkrbacb/ee7d708e97835d0b04fd7362f7fffab4.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpu13xha/34086a3eb35a43a5db36cdd97c1264c0.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpu13xha/34086a3eb35a43a5db36cdd97c1264c0.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpbs6dbi/e8da842e90e44de224f835542fc1e2ae.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpbs6dbi/e8da842e90e44de224f835542fc1e2ae.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpfybfqm/7ee100cbdb680ad745f170ff10a30cb2.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpfybfqm/7ee100cbdb680ad745f170ff10a30cb2.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpg0g7v5/873e5f76435b747fb893ffbe861c95ce.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpg0g7v5/873e5f76435b747fb893ffbe861c95ce.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpsqupgj/4bb8bc707aa2239dc4305d802275b70c.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpsqupgj/4bb8bc707aa2239dc4305d802275b70c.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpe3iqtx/a75fe51b78cd45e598008b19e82e1aec.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpe3iqtx/a75fe51b78cd45e598008b19e82e1aec.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmprpppwo/d86d83a5d159e38c79fcf6bb0433dd6b.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmprpppwo/d86d83a5d159e38c79fcf6bb0433dd6b.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpnfshc1/a603235c3c113e1e9c88266847da4c52.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpnfshc1/a603235c3c113e1e9c88266847da4c52.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpeqjvda/117afbf4b3a16f88a4aaf106ac253643.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpeqjvda/117afbf4b3a16f88a4aaf106ac253643.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp4xv4ig/c681fcf5bbe152c01758bbb9b0190e70.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp4xv4ig/c681fcf5bbe152c01758bbb9b0190e70.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvu9hcj/714af1ebd844e20a5db4bb4fe004c16f.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvu9hcj/714af1ebd844e20a5db4bb4fe004c16f.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp8ry1dz/0aa6f61d7441d8de3bf3bd8ba96be773.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp8ry1dz/0aa6f61d7441d8de3bf3bd8ba96be773.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmplyozav/acc38466b1518a5ca08862c253234fcc.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmplyozav/acc38466b1518a5ca08862c253234fcc.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp3_qjia/f4bc5f0f5a04ec65ea171fe97906207b.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp3_qjia/f4bc5f0f5a04ec65ea171fe97906207b.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpu2beb9/cf6ff5a70309ece9643a2f655c4a0aee.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpu2beb9/cf6ff5a70309ece9643a2f655c4a0aee.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpzbbgly/280ad885ae64821d6b569ce4c2d76d00.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpzbbgly/280ad885ae64821d6b569ce4c2d76d00.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpju4nul/7b11126a8f1c7ed0fc20d3a7e583e20b.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpju4nul/7b11126a8f1c7ed0fc20d3a7e583e20b.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpqd4sl0/b233f0f87ef61166028f20f834bf8cfa.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpqd4sl0/b233f0f87ef61166028f20f834bf8cfa.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpi9heon/7ca4b5929ce3b49ba9aa719ba35ce182.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpi9heon/7ca4b5929ce3b49ba9aa719ba35ce182.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpo2cmt6/adb95000fb2d8b41c5f4822585a03d95.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpo2cmt6/adb95000fb2d8b41c5f4822585a03d95.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpdfkdt7/ad4c9bf5ddd3b88c9f5fe6ce7ca9acde.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpdfkdt7/ad4c9bf5ddd3b88c9f5fe6ce7ca9acde.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpblneyf/527ba1ef4c104cb512297b39906da534.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpblneyf/527ba1ef4c104cb512297b39906da534.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpmcogrb/c51f8f24e1a7e43920bf87eafb113d1b.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpmcogrb/c51f8f24e1a7e43920bf87eafb113d1b.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpyq2p2h/5519a255332f08fa226d3ec32fb76ff1.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpyq2p2h/5519a255332f08fa226d3ec32fb76ff1.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvs3j4s/4999976f198e35d397d20ba1f36ce773.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvs3j4s/4999976f198e35d397d20ba1f36ce773.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp2pizml/b450a59c662bdb734ee3829a5830f918.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp2pizml/b450a59c662bdb734ee3829a5830f918.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpgumqye/ed4d31a668941a541a813c19404489db.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpgumqye/ed4d31a668941a541a813c19404489db.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpujbm3q/bc72702e23f23926b05bb81840129776.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpujbm3q/bc72702e23f23926b05bb81840129776.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpcdz39h/f8709d154c0eec850230849fad8a043c.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpcdz39h/f8709d154c0eec850230849fad8a043c.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmplwrlco/022c6797fa74723b3c31f12927a5da67.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmplwrlco/022c6797fa74723b3c31f12927a5da67.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp80qqgs/c7d9cba981f4e8e280e7249dcf10e4d7.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp80qqgs/c7d9cba981f4e8e280e7249dcf10e4d7.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmppcmihp/e9d45cf8a8c72ebe4bf1941dda86ec95.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmppcmihp/e9d45cf8a8c72ebe4bf1941dda86ec95.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpghptrj/c91710f781c9cd72adc4be6363ec9aa7.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpghptrj/c91710f781c9cd72adc4be6363ec9aa7.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpmiplul/1c220bd4a073bcb41898b55eccf62054.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpmiplul/1c220bd4a073bcb41898b55eccf62054.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp4hmcmz/1952c4216b25407beccfe520b7123651.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp4hmcmz/1952c4216b25407beccfe520b7123651.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpr50wid/9e0a35f5a8d2cae247db72ec1e58e39e.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpr50wid/9e0a35f5a8d2cae247db72ec1e58e39e.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptusm6s/d6e5b517fd78340c42549e46f11ae55a.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptusm6s/d6e5b517fd78340c42549e46f11ae55a.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvskdma/29b3d466be01fa41426d5f229f0ed33e.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvskdma/29b3d466be01fa41426d5f229f0ed33e.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvo9kfu/0e8d45aa8335bbc9b7477411a05bc380.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvo9kfu/0e8d45aa8335bbc9b7477411a05bc380.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpmlqaft/407a0c098bc4f4e80a8388758124e728.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpmlqaft/407a0c098bc4f4e80a8388758124e728.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpscn_jh/a39fe7099f3d2084bcf5dcb53d8abc46.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpscn_jh/a39fe7099f3d2084bcf5dcb53d8abc46.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpbx2wyi/80474603565cd1c576a4c421a26c7ca2.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpbx2wyi/80474603565cd1c576a4c421a26c7ca2.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpxouvzy/4b5f278f576be5accf1cefe8c01d8b1c.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpxouvzy/4b5f278f576be5accf1cefe8c01d8b1c.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptx_frp/48c70f32793a255acbc4c394274c6fec.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptx_frp/48c70f32793a255acbc4c394274c6fec.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpk4taw5/afa734208645bfc733c4fc1332c42aa7.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpk4taw5/afa734208645bfc733c4fc1332c42aa7.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmppydmp0/c6b314dbc9ca88245503b9bb4de1dd57.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmppydmp0/c6b314dbc9ca88245503b9bb4de1dd57.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpnxncn2/745a209e1e9d5f451c450ff2abc8ce77.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpnxncn2/745a209e1e9d5f451c450ff2abc8ce77.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpqmuyfv/5bafac1542ff0fc8bdad8e2a8e300c7d.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpqmuyfv/5bafac1542ff0fc8bdad8e2a8e300c7d.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpam3pds/3c2668e6be5e09039a4279cb1c4bbf1c.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpam3pds/3c2668e6be5e09039a4279cb1c4bbf1c.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpyghjzg/355ee13374f187737edd3d9fd998f352.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpyghjzg/355ee13374f187737edd3d9fd998f352.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpydhrml/9f7252612357dfbba960b73f2384436c.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpydhrml/9f7252612357dfbba960b73f2384436c.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvgqylp/b5a06e86df9fc86c408fae9a4462ba8d.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpvgqylp/b5a06e86df9fc86c408fae9a4462ba8d.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmppumhmz/322152ea87aada237172557b8fa7f9a0.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmppumhmz/322152ea87aada237172557b8fa7f9a0.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpyxu9it/1ce354b9b5f74ac00b705368af0ba1f0.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpyxu9it/1ce354b9b5f74ac00b705368af0ba1f0.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpjtzli8/6abc3ce8fe8ca9d51baf1cb2730f7a23.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpjtzli8/6abc3ce8fe8ca9d51baf1cb2730f7a23.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp3xnayx/dabac08b9253c2b7cc78cddd08c091ec.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp3xnayx/dabac08b9253c2b7cc78cddd08c091ec.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptgqiry/1806a9845e77d8661e741f4e9132a198.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmptgqiry/1806a9845e77d8661e741f4e9132a198.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp9evw9r/c67af7ab99b9a8d56cccb507985a475c.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmp9evw9r/c67af7ab99b9a8d56cccb507985a475c.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpudllnm/ed3c82e51686e4eabf705a844dcbb4bc.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpudllnm/ed3c82e51686e4eabf705a844dcbb4bc.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmprjm9vx/918d67d2ed37387ca3acdc3cdaa8320b.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmprjm9vx/918d67d2ed37387ca3acdc3cdaa8320b.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpglguia/c70c7d011efa584883336c3a816a4b4b.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpglguia/c70c7d011efa584883336c3a816a4b4b.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpqd2ord/220b3b50f5e27116c42c7198aceb007c.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpqd2ord/220b3b50f5e27116c42c7198aceb007c.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpuvyzxs/151fc90aab6b3a35cddfd3f45e153b67.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpuvyzxs/151fc90aab6b3a35cddfd3f45e153b67.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpuqbuzx/46971aa7fd82da8775d2da7939474cf5.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpuqbuzx/46971aa7fd82da8775d2da7939474cf5.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpi1kz6f/8618bdab9d335e20a23059636b6f76da.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpi1kz6f/8618bdab9d335e20a23059636b6f76da.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpd02jxa/5fb81a1aa3eefc673ceb6d17a184d1fe.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpd02jxa/5fb81a1aa3eefc673ceb6d17a184d1fe.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpdxzdoe/82b666716f9f6cc8fff4fec54d9ed032.lib and object C:/Users/p2admin/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_62_Stepping_4_GenuineIntel-2.7.12-64/tmpdxzdoe/82b666716f9f6cc8fff4fec54d9ed032.exp

# %%
keras.optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(loss='mae', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=500,verbose=1, validation_data=(X_test, Y_test))

# %%
Y_test-model.predict(X_test)
# Out:
# array([[ 0.0598288 ],
#        [-0.22975894],
#        [ 0.02204274],
#        [ 0.16350582],
#        [-0.26330754],
#        [-0.18016099],
#        [-0.46485456],
#        [-0.32365561],
#        [ 0.09812948],
#        [ 0.10863168],
#        [-0.24898307],
#        [-0.01799552],
#        [ 0.07780188],
#        [-0.09783778],
#        [-0.14135144],
#        [ 0.2093093 ],
#        [-0.05261862],
#        [ 0.20715234],
#        [ 0.10180938],
#        [ 0.39897717]])

# %%
model = get_residual_model(is_mnist=is_mnist, img_channels=img_channels, img_rows=img_rows, img_cols=img_cols)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# autosave best Model
best_model_file = "./my_model_weights.h5"
best_model = ModelCheckpoint(best_model_file, verbose=1, save_best_only=True)

model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch,
          verbose=1, validation_data=(X_test, Y_test))#, callbacks=[best_model])
score = model.evaluate(X_test, Y_test, show_accuracy=True, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])

# %%
model.evaluate(X_test, Y_test, show_accuracy=True, verbose=0)
# Out:
# [0.14737975597381592, 0.0]

# %%
'''Example of using residual_blocks.py by Keunwoo Choi (keunwoo.choi@qmul.ac.uk), on Keras 0.3.2
It's copy-and-pasted from the code I am using, so it wouldn't run.
Just take a look to understand how to use residual blocks. 

The whole structure is...

   -------Residual Model (keras.models.Sequential())-------
   |                                                      |
   |     ---- Residual blocks ------------------------|   |
   |     |    (keras.layers.containers.Sequential())  |   |
   |     |                                            |   |
   |     |     -- Many Residual blocks ------------   |   |
   |     |     | (keras.layers.containers.Graph())|   |   |
   |     |     |                                  |   |   |
   |     |     |__________________________________|   |   |
   |     |____________________________________________|   |
   |                                                      |
   |______________________________________________________|

'''
from __future__ import print_function
import sys
sys.setrecursionlimit(99999)
import pdb

import numpy as np
np.random.seed(1337)  # for reproducibility

import keras

from keras.datasets import mnist, cifar10
from keras.models import Sequential, Graph
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import ZeroPadding2D, AveragePooling2D, Convolution2D
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras.layers.normalization import BatchNormalization

import residual_blocks


batch_size = 10
nb_classes = 1
nb_epoch = 20

def compute_padding_length(length_before, stride, length_conv):
    ''' Assumption: you want the subsampled result has a length of floor(original_length/stride).
    '''
    N = length_before
    F = length_conv
    S = stride
    if S == F:
        return 0
    if S == 1:
        return (F-1)/2
    for P in range(S):
        if (N-F+2*P)/S + 1 == N/S:
            return P
    return None

def design_for_residual_blocks(num_channel_input=1):
    ''''''
    model = Sequential() # it's a CONTAINER, not MODEL
    # set numbers
    num_big_blocks = 5
    image_patch_sizes = [[3,3]]*num_big_blocks
    pool_sizes = [(2,2)]*num_big_blocks
    n_features =      [128, 256, 512, 512, 1024]
    n_features_next = [256, 512, 512, 512, 1024]
    height_input = 148
    width_input = 148
    for conv_idx in range(num_big_blocks):    
        n_feat_here = n_features[conv_idx]
        # residual block 0
        model.add(residual_blocks.building_residual_block(  (num_channel_input, height_input, width_input),
                                                            n_feat_here,
                                                            kernel_sizes=image_patch_sizes[conv_idx]
                                                            ))

        # residual block 1 (you can add it as you want (and your resources allow..))
        if False:
            model.add(residual_blocks.building_residual_block(  (n_feat_here, height_input, width_input),
                                                                n_feat_here,
                                                                kernel_sizes=image_patch_sizes[conv_idx]
                                                                ))
        
        # the last residual block N-1
        # the last one : pad zeros, subsamples, and increase #channels
        pad_height = compute_padding_length(height_input, pool_sizes[conv_idx][0], image_patch_sizes[conv_idx][0])
        pad_width = compute_padding_length(width_input, pool_sizes[conv_idx][1], image_patch_sizes[conv_idx][1])
        model.add(ZeroPadding2D(padding=(pad_height,pad_width))) 
        height_input += 2*pad_height
        width_input += 2*pad_width
        n_feat_next = n_features_next[conv_idx]
        model.add(residual_blocks.building_residual_block(  (n_feat_here, height_input, width_input),
                                                            n_feat_next,
                                                            kernel_sizes=image_patch_sizes[conv_idx],
                                                            is_subsample=True,
                                                            subsample=pool_sizes[conv_idx]
                                                            ))

        height_input, width_input = model.output_shape[2:]
        # width_input  = int(width_input/pool_sizes[conv_idx][1])
        num_channel_input = n_feat_next

    # Add average pooling at the end:
    print('Average pooling, from (%d,%d) to (1,1)' % (height_input, width_input))
    model.add(AveragePooling2D(pool_size=(height_input, width_input)))

    return model

def get_residual_model(is_mnist=True, img_channels=1, img_rows=28, img_cols=28):
    model = keras.models.Sequential()
    first_layer_channel = 128
    if is_mnist: # size to be changed to 32,32
        model.add(ZeroPadding2D((2,2), input_shape=(img_channels, img_rows, img_cols))) # resize (28,28)-->(32,32)
        # the first conv 
        model.add(Convolution2D(first_layer_channel, 3, 3, border_mode='same'))
    else:
        model.add(Convolution2D(first_layer_channel, 3, 3, border_mode='same', input_shape=(img_channels, img_rows, img_cols)))

    model.add(Activation('relu'))
    # [residual-based Conv layers]
    residual_blocks = design_for_residual_blocks(num_channel_input=first_layer_channel)
    model.add(residual_blocks)
    model.add(BatchNormalization(axis=1))
    model.add(Activation('relu'))
    # [Classifier]    
    model.add(Flatten())
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    # [END]
    return model

if __name__ =='__main__':

    is_mnist = True
    is_cifar10 = not is_mnist

    if is_mnist:
        import scipy.io as sio
        import numpy as np

        img_rows, img_cols = 144, 144
        img_channels = 1
        WB = sio.loadmat('WB_small.mat')['WB_small']
        Y_data = sio.loadmat('true.mat')['skt']
        Y_data = (Y_data - min(Y_data)) / (max(Y_data) - min(Y_data))
        X_data = np.reshape(WB, (100, 1, img_rows, img_cols))
        X_train = X_data[0:80];
        X_test = X_data[80:100]
        Y_train = Y_data[0:80];
        Y_test = Y_data[80:100]
        print(' == MNIST ==')
    else:
        (X_train, y_train), (X_test, y_test) = cifar10.load_data()
        img_rows, img_cols = 32, 32
        img_channels = 3
        print(' == CIFAR10 ==')

    X_train = X_train.reshape(X_train.shape[0], img_channels, img_rows, img_cols)
    X_test = X_test.reshape(X_test.shape[0], img_channels, img_rows, img_cols)
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    # X_train /= 255
    # X_test /= 255
    # X_train = (X_train - np.mean(X_train))/np.std(X_train)
    # X_test = (X_test - np.mean(X_test))/np.std(X_test)
    print('X_train shape:', X_train.shape)
    print(X_train.shape[0], 'train samples')
    print(X_test.shape[0], 'test samples')

    model = get_residual_model(is_mnist=is_mnist, img_channels=img_channels, img_rows=img_rows, img_cols=img_cols)

    model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

    # # autosave best Model
    # best_model_file = "./my_model_weights.h5"
    # best_model = ModelCheckpoint(best_model_file, verbose=1, save_best_only=True)
    #
#     model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch, verbose=1, validation_data=(X_test, Y_test))#, callbacks=[best_model])
    # score = model.evaluate(X_test, Y_test, show_accuracy=True, verbose=0)
    # print('Test score:', score[0])
    # print('Test accuracy:', score[1])
# Out:
#  == MNIST ==
# X_train shape: (80L, 1L, 144L, 144L)
# 80 train samples
# 20 test samples
#    - New residual block with
# ('      input shape:', (128, 148, 148))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (128, 150, 150))
# ('      kernel size:', [3, 3])
#       - Input channels: 128 ---> num feature maps on out: 256
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (256, 74, 74))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (256, 76, 76))
# ('      kernel size:', [3, 3])
#       - Input channels: 256 ---> num feature maps on out: 512
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 37, 37))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 37, 37))
# ('      kernel size:', [3, 3])
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 18, 18))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 20, 20))
# ('      kernel size:', [3, 3])
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 9, 9))
# ('      kernel size:', [3, 3])
#       - Input channels: 512 ---> num feature maps on out: 1024
#         -- model was built.
#    - New residual block with
# ('      input shape:', (1024, 9, 9))
# ('      kernel size:', [3, 3])
# ('      - with subsample:', (2, 2))
#         -- model was built.
# Average pooling, from (4,4) to (1,1)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# zeropadding2d_5 (ZeroPadding2D)  (None, 1, 148, 148)   0           zeropadding2d_input_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D) (None, 128, 148, 148) 1280        zeropadding2d_5[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 128, 148, 148) 0           convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# sequential_4 (Sequential)        (None, 1024, 1, 1)    73990912    activation_16[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_34 (BatchNorma(None, 1024, 1, 1)    2048        sequential_4[1][0]
# ____________________________________________________________________________________________________
# activation_37 (Activation)       (None, 1024, 1, 1)    0           batchnormalization_34[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 1024)          0           activation_37[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 1)             1025        flatten_2[0][0]
# ____________________________________________________________________________________________________
# activation_38 (Activation)       (None, 1)             0           dense_2[0][0]
# ====================================================================================================
# Total params: 73995265
# ____________________________________________________________________________________________________

# %%
'''Example of using residual_blocks.py by Keunwoo Choi (keunwoo.choi@qmul.ac.uk), on Keras 0.3.2
It's copy-and-pasted from the code I am using, so it wouldn't run.
Just take a look to understand how to use residual blocks. 

The whole structure is...

   -------Residual Model (keras.models.Sequential())-------
   |                                                      |
   |     ---- Residual blocks ------------------------|   |
   |     |    (keras.layers.containers.Sequential())  |   |
   |     |                                            |   |
   |     |     -- Many Residual blocks ------------   |   |
   |     |     | (keras.layers.containers.Graph())|   |   |
   |     |     |                                  |   |   |
   |     |     |__________________________________|   |   |
   |     |____________________________________________|   |
   |                                                      |
   |______________________________________________________|

'''
from __future__ import print_function
import sys
sys.setrecursionlimit(99999)
import pdb

import numpy as np
np.random.seed(1337)  # for reproducibility

import keras

from keras.datasets import mnist, cifar10
from keras.models import Sequential, Graph
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import ZeroPadding2D, AveragePooling2D, Convolution2D
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras.layers.normalization import BatchNormalization

import residual_blocks


batch_size = 10
nb_classes = 1
nb_epoch = 20

def compute_padding_length(length_before, stride, length_conv):
    ''' Assumption: you want the subsampled result has a length of floor(original_length/stride).
    '''
    N = length_before
    F = length_conv
    S = stride
    if S == F:
        return 0
    if S == 1:
        return (F-1)/2
    for P in range(S):
        if (N-F+2*P)/S + 1 == N/S:
            return P
    return None

def design_for_residual_blocks(num_channel_input=1):
    ''''''
    model = Sequential() # it's a CONTAINER, not MODEL
    # set numbers
    num_big_blocks = 5
    image_patch_sizes = [[3,3]]*num_big_blocks
    pool_sizes = [(2,2)]*num_big_blocks
    n_features =      [128, 256, 512, 512, 1024]
    n_features_next = [256, 512, 512, 512, 1024]
    height_input = 148
    width_input = 148
    for conv_idx in range(num_big_blocks):    
        n_feat_here = n_features[conv_idx]
        # residual block 0
        model.add(residual_blocks.building_residual_block(  (num_channel_input, height_input, width_input),
                                                            n_feat_here,
                                                            kernel_sizes=image_patch_sizes[conv_idx]
                                                            ))

        # residual block 1 (you can add it as you want (and your resources allow..))
        if False:
            model.add(residual_blocks.building_residual_block(  (n_feat_here, height_input, width_input),
                                                                n_feat_here,
                                                                kernel_sizes=image_patch_sizes[conv_idx]
                                                                ))
        
        # the last residual block N-1
        # the last one : pad zeros, subsamples, and increase #channels
        pad_height = compute_padding_length(height_input, pool_sizes[conv_idx][0], image_patch_sizes[conv_idx][0])
        pad_width = compute_padding_length(width_input, pool_sizes[conv_idx][1], image_patch_sizes[conv_idx][1])
        model.add(ZeroPadding2D(padding=(pad_height,pad_width))) 
        height_input += 2*pad_height
        width_input += 2*pad_width
        n_feat_next = n_features_next[conv_idx]
        model.add(residual_blocks.building_residual_block(  (n_feat_here, height_input, width_input),
                                                            n_feat_next,
                                                            kernel_sizes=image_patch_sizes[conv_idx],
                                                            is_subsample=True,
                                                            subsample=pool_sizes[conv_idx]
                                                            ))

        height_input, width_input = model.output_shape[2:]
        # width_input  = int(width_input/pool_sizes[conv_idx][1])
        num_channel_input = n_feat_next

    # Add average pooling at the end:
    print('Average pooling, from (%d,%d) to (1,1)' % (height_input, width_input))
    model.add(AveragePooling2D(pool_size=(height_input, width_input)))

    return model

def get_residual_model(is_mnist=True, img_channels=1, img_rows=28, img_cols=28):
    model = keras.models.Sequential()
    first_layer_channel = 128
    if is_mnist: # size to be changed to 32,32
        model.add(ZeroPadding2D((2,2), input_shape=(img_channels, img_rows, img_cols))) # resize (28,28)-->(32,32)
        # the first conv 
        model.add(Convolution2D(first_layer_channel, 3, 3, border_mode='same'))
    else:
        model.add(Convolution2D(first_layer_channel, 3, 3, border_mode='same', input_shape=(img_channels, img_rows, img_cols)))

    model.add(Activation('relu'))
    # [residual-based Conv layers]
    residual_blocks = design_for_residual_blocks(num_channel_input=first_layer_channel)
    model.add(residual_blocks)
    model.add(BatchNormalization(axis=1))
    model.add(Activation('relu'))
    # [Classifier]    
    model.add(Flatten())
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    # [END]
    return model

if __name__ =='__main__':

    is_mnist = True
    is_cifar10 = not is_mnist

    if is_mnist:
        import scipy.io as sio
        import numpy as np

        img_rows, img_cols = 144, 144
        img_channels = 1
        WB = sio.loadmat('WB_small.mat')['WB_small']
        Y_data = sio.loadmat('true.mat')['skt']
        Y_data = (Y_data - min(Y_data)) / (max(Y_data) - min(Y_data))
        X_data = np.reshape(WB, (100, 1, img_rows, img_cols))
        X_train = X_data[0:80];
        X_test = X_data[80:100]
        Y_train = Y_data[0:80];
        Y_test = Y_data[80:100]
        print(' == MNIST ==')
    else:
        (X_train, y_train), (X_test, y_test) = cifar10.load_data()
        img_rows, img_cols = 32, 32
        img_channels = 3
        print(' == CIFAR10 ==')

    X_train = X_train.reshape(X_train.shape[0], img_channels, img_rows, img_cols)
    X_test = X_test.reshape(X_test.shape[0], img_channels, img_rows, img_cols)
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    # X_train /= 255
    # X_test /= 255
    # X_train = (X_train - np.mean(X_train))/np.std(X_train)
    # X_test = (X_test - np.mean(X_test))/np.std(X_test)
    print('X_train shape:', X_train.shape)
    print(X_train.shape[0], 'train samples')
    print(X_test.shape[0], 'test samples')

    model = get_residual_model(is_mnist=is_mnist, img_channels=img_channels, img_rows=img_rows, img_cols=img_cols)

    model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

    # # autosave best Model
    # best_model_file = "./my_model_weights.h5"
    # best_model = ModelCheckpoint(best_model_file, verbose=1, save_best_only=True)
    #
#     model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch, verbose=1, validation_data=(X_test, Y_test))#, callbacks=[best_model])
    # score = model.evaluate(X_test, Y_test, show_accuracy=True, verbose=0)
    # print('Test score:', score[0])
    # print('Test accuracy:', score[1])
# Out:
#  == MNIST ==
# X_train shape: (80L, 1L, 144L, 144L)
# 80 train samples
# 20 test samples
#    - New residual block with
# ('      input shape:', (128, 148, 148))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (128, 150, 150))
# ('      kernel size:', [3, 3])
#       - Input channels: 128 ---> num feature maps on out: 256
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (256, 74, 74))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (256, 76, 76))
# ('      kernel size:', [3, 3])
#       - Input channels: 256 ---> num feature maps on out: 512
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 37, 37))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 37, 37))
# ('      kernel size:', [3, 3])
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 18, 18))
# ('      kernel size:', [3, 3])
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 20, 20))
# ('      kernel size:', [3, 3])
# ('      - with subsample:', (2, 2))
#         -- model was built.
#    - New residual block with
# ('      input shape:', (512, 9, 9))
# ('      kernel size:', [3, 3])
#       - Input channels: 512 ---> num feature maps on out: 1024
#         -- model was built.
#    - New residual block with
# ('      input shape:', (1024, 9, 9))
# ('      kernel size:', [3, 3])
# ('      - with subsample:', (2, 2))
#         -- model was built.
# Average pooling, from (4,4) to (1,1)
